# %%
tasks = []
def show_menu():
  print ("1. Add Task")
  print ("2. View Task")
  print ("3. Remove Task")
  print ("4. Exit")

def add_task():
  task = input ("Enter Task: ")
  tasks.append (task)
  print(" Task Added Successfully!  ")

def view_task():
  if len(tasks) == 0:
    print("No Task Available: ")
  else:
    print("Your Tasks:")
    for i, task in enumerate (tasks, start=1):
      print(f"{i}.{task}")

def remove_task():
  view_task()
  if len (tasks) > 0:
    num = int(input("Enter Task Number to Remove :"))
    if 1 <= num  <= len(tasks):
      removed = tasks.pop(num - 1)
      print(f"X Task Removed: {removed}")
    else:
      print("Invalid Task Number!")

while True:
  show_menu()
  choice = input ("Enter the Choice (1 - 4 ):")

  if choice == "1":
    add_task()

  elif choice == "2":
    view_task()

  elif choice == "3":
    remove_task()

  elif choice == '4':
    print ("Exit!")
    break

  else:
    print ("Invalid Choice! Please Try Again!")
# Out:
# 1. Add Task
# 2. View Task
# 3. Remove Task
# 4. Exit
# Enter the Choice (1 - 4 ):1
# Enter Task: Do the code
#  Task Added Successfully!
# 1. Add Task
# 2. View Task
# 3. Remove Task
# 4. Exit
# Enter the Choice (1 - 4 ):2
# Your Tasks:
# 1.Do the code
# 1. Add Task
# 2. View Task
# 3. Remove Task
# 4. Exit
# Enter the Choice (1 - 4 ):1
# Enter Task: Find the error in Code
#  Task Added Successfully!
# 1. Add Task
# 2. View Task
# 3. Remove Task
# 4. Exit
# Enter the Choice (1 - 4 ):2
# Your Tasks:
# 1.Do the code
# 2.Find the error in Code
# 1. Add Task
# 2. View Task
# 3. Remove Task
# 4. Exit
# Enter the Choice (1 - 4 ):3
# Your Tasks:
# 1.Do the code
# 2.Find the error in Code
# Enter Task Number to Remove :1
# X Task Removed: Do the code
# 1. Add Task
# 2. View Task
# 3. Remove Task
# 4. Exit
# Enter the Choice (1 - 4 ):2
# Your Tasks:
# 1.Find the error in Code
# 1. Add Task
# 2. View Task
# 3. Remove Task
# 4. Exit
# Enter the Choice (1 - 4 ):2
# Your Tasks:
# 1.Find the error in Code
# 1. Add Task
# 2. View Task
# 3. Remove Task
# 4. Exit
# Enter the Choice (1 - 4 ):4
# Exit!
